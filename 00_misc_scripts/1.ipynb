# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Access the variables
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
print(f"API Key: {OPENAI_API_KEY}")

# %%
from openai import OpenAI
client = OpenAI()
response = client.responses.create(
    model="gpt-5",
    input="What is the stock price of Apple?"
)
print(response.output_text)

# %%
bio="Pavan is a data scientist working for a nasa related project. He loves to play chess and is a foodie."

# %%
from openai import OpenAI
client = OpenAI()
response = client.responses.create(
    model="gpt-5",
    input=f"Write a short blog on {bio}."
)
print(response.output_text)

# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-5.2",
    tools=[{"type": "web_search"}],
    input="What is 50 multiplied by 2?"
)

print(response.output_text)
