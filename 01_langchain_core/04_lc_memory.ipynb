# %%
import os
from getpass import getpass
from langchain_openai import ChatOpenAI

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY") or \
    getpass("Enter your OpenAI API key: ")

# For normal accurate responses
llm = ChatOpenAI(temperature=0.0, model="gpt-4o-mini")

# %%
from langchain_classic.memory.buffer import ConversationBufferMemory

memory = ConversationBufferMemory(return_messages=True)

# %%
from langchain_classic.chains import ConversationChain

newchain = ConversationChain(
    llm=llm,
    memory=memory,
    verbose=False
)

# %%
newchain.invoke({"input": "what is my name again?"})

# %%
result=newchain.invoke({"input": "what is my name again?"})
print(result)

# %%
result=newchain.invoke({"input": "hey i'm rakesh garapati , i want to write a movie story?"})
print(result)

# %%
result=newchain.invoke({"input": "do you know about this celebrity called sampoornesh babu?"})
print(result)

# %%
result=newchain.invoke({"input": "what is my name again?"})
print(result)
